# %%
print("who are you?")
# Out:
# who are you?

# %%
def greet(name):
    return f"Hello, {name}!"

# %%
name = "Alice"
print(greet(name))
# Out:
# Hello, Alice!

# %%
print("i know you")
# Out:
# i know you

# %%
print("my name is manas singh")
# Out:
# my name is manas singh

# %%
print("hello world")
# Out:
# hello world

# %%
print("here")
# Out:
# here

# %%
print("i am back")
# Out:
# i am back
