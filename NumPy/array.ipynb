# %%
import numpy as np

# %%
arr = np.array([1,2,3,4,5])
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
l = ([[1, 2,3],[4,5,6], [7,8,9]])
l
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
arr = np.array(l)
print(arr)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]
